# %% [markdown]
# <h1> Activity 1: Palmer's Penguin Data Analyst Project</h1>
# <hr>
# <h3> Analyst: Jimuel G. Perez</h3>

# %%
#import Libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import f_oneway

# %% [markdown]
# <h3>Converting DataSet(s) into DataFrame</h3>
# <h1>Requirements:</h1>
# <ul>
#     <li>
#         Name of the Dataframe
#     </li>
#     <li>
#         File Path
#     </li>
# </ul>

# %%
penguins = pd.read_csv("DataSets\\penguins.csv")

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
penguins.isnull()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False           False          False              False
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex   year
# 0          False  False  False
# 1          False  False  False
# ...

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h3>Filter Column</h3>

# %%
penguins['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
penguins ['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
Chinstrap_DF = penguins[penguins['species'] == 'Chinstrap']

# %%
Adelie_DF = penguins[penguins['species'] == 'Adelie']

# %%
Chinstrap_DF
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
penguins[penguins['species'] == 'Gentoo']
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Gentoo  Biscoe            46.1           13.2              211.0
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 154  Gentoo  Biscoe            48.7           14.1              210.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 271  Gentoo  Biscoe             NaN            NaN                NaN
# 272  Gentoo  Biscoe            46.8           14.3              215.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 152       4500.0  female  2007
# 153       5700.0    male  2007
# ...

# %%
Adelie_DF
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
penguins['body_mass_g'] >= 4000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342     True
# 343    False
# Name: body_mass_g, Length: 344, dtype: bool

# %%
penguins[penguins['body_mass_g'] >= 4000]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 7       Adelie  Torgersen            39.2           19.6              195.0
# 9       Adelie  Torgersen            42.0           20.2              190.0
# 14      Adelie  Torgersen            34.6           21.1              198.0
# 17      Adelie  Torgersen            42.5           20.7              197.0
# 19      Adelie  Torgersen            46.0           21.5              194.0
# ..         ...        ...             ...            ...                ...
# 323  Chinstrap      Dream            49.0           19.6              212.0
# 329  Chinstrap      Dream            50.7           19.7              203.0
# 333  Chinstrap      Dream            49.3           19.9              203.0
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
#
#      body_mass_g   sex  year
# ...

# %%
penguins[(penguins['species'] == 'Adelie') & (penguins['body_mass_g'] >= 4000)]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# 17   Adelie  Torgersen            42.5           20.7              197.0
# 19   Adelie  Torgersen            46.0           21.5              194.0
# 35   Adelie      Dream            39.2           21.1              196.0
# 39   Adelie      Dream            39.8           19.1              184.0
# 43   Adelie      Dream            44.1           19.7              196.0
# 45   Adelie      Dream            39.6           18.8              190.0
# 49   Adelie      Dream            42.3           21.2              191.0
# 51   Adelie     Biscoe            40.1           18.9              188.0
# 53   Adelie     Biscoe            42.0           19.5              200.0
# ...

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
penguins['bill_length_mm'] = penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mean())
penguins['bill_depth_mm'] = penguins['bill_depth_mm'].fillna(penguins['bill_depth_mm'].mean())
penguins['flipper_length_mm'] = penguins['flipper_length_mm'].fillna(penguins['flipper_length_mm'].mean())
penguins['body_mass_g'] = penguins['body_mass_g'].fillna(penguins['body_mass_g'].mean())
penguins['sex'] = penguins['sex'].fillna(penguins['sex'].mode()[0])

# %%
penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# <h3>Changing Data Types</h3>

# %%
penguins['species'] = penguins['species'].astype('category')
penguins['year'] = penguins['year'].astype('category')

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      344.000000     344.000000         344.000000   344.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.443643       1.969027          14.020657   799.613058
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.275000      15.600000         190.000000  3550.000000
# 50%         44.250000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# <h1> How to create Column</h1>

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    object
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    object
#  7   year               344 non-null    category
# dtypes: category(2), float64(4), object(2)
# memory usage: 17.2+ KB

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
penguins['mass_kg'] = np.round(penguins ['body_mass_g'] / 1000 , 1)

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen        39.10000       18.70000         181.000000
# 1       Adelie  Torgersen        39.50000       17.40000         186.000000
# 2       Adelie  Torgersen        40.30000       18.00000         195.000000
# 3       Adelie  Torgersen        43.92193       17.15117         200.915205
# 4       Adelie  Torgersen        36.70000       19.30000         193.000000
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream        55.80000       19.80000         207.000000
# 340  Chinstrap      Dream        43.50000       18.10000         202.000000
# 341  Chinstrap      Dream        49.60000       18.20000         193.000000
# 342  Chinstrap      Dream        50.80000       19.00000         210.000000
# 343  Chinstrap      Dream        50.20000       18.70000         198.000000
#
#      body_mass_g     sex  year  mass_kg
# ...

# %%
penguins['mass_kg'].min()
# Out:
# np.float64(2.7)

# %%
penguins[penguins['mass_kg'] == 2.7]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 314  Chinstrap  Dream            46.9           16.6              192.0
#
#      body_mass_g     sex  year  mass_kg
# 314       2700.0  female  2008      2.7

# %%
penguins['mass_kg'].max()
# Out:
# np.float64(6.3)

# %%
penguins[penguins['mass_kg'] == 6.3]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 169  Gentoo  Biscoe            49.2           15.2              221.0
#
#      body_mass_g   sex  year  mass_kg
# 169       6300.0  male  2007      6.3

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen        39.10000       18.70000         181.000000
# 1       Adelie  Torgersen        39.50000       17.40000         186.000000
# 2       Adelie  Torgersen        40.30000       18.00000         195.000000
# 3       Adelie  Torgersen        43.92193       17.15117         200.915205
# 4       Adelie  Torgersen        36.70000       19.30000         193.000000
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream        55.80000       19.80000         207.000000
# 340  Chinstrap      Dream        43.50000       18.10000         202.000000
# 341  Chinstrap      Dream        49.60000       18.20000         193.000000
# 342  Chinstrap      Dream        50.80000       19.00000         210.000000
# 343  Chinstrap      Dream        50.20000       18.70000         198.000000
#
#      body_mass_g     sex  year  mass_kg
# ...

# %%
penguins['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: category
# Categories (3, object): ['Adelie', 'Chinstrap', 'Gentoo']

# %%
peng_isl = penguins['island'].value_counts()

# %% [markdown]
# <h3>Explanatory Data Analytics</h3>

# %% [markdown]
# <h3> 1. Where is the habitat of the Heaviest specie?</h3>

# %%
penguins['mass_kg'].max()
# Out:
# np.float64(6.3)

# %%
penguins[penguins['mass_kg'] == 6.3]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 169  Gentoo  Biscoe            49.2           15.2              221.0
#
#      body_mass_g   sex  year  mass_kg
# 169       6300.0  male  2007      6.3

# %% [markdown]
# <h3>Insight:</h3>
# <h5>The Heaviest Specie live in Biscoe</h4>
# <hr>

# %% [markdown]
# <h3>2. Which is the Lightest Female Specie?</h3>

# %%
penguins['mass_kg'].min()
# Out:
# np.float64(2.7)

# %%
penguins[penguins['mass_kg'] == 2.7]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 314  Chinstrap  Dream            46.9           16.6              192.0
#
#      body_mass_g     sex  year  mass_kg
# 314       2700.0  female  2008      2.7

# %% [markdown]
# <h3>Insight:</h3>
# <h5>Chinstrap is the lightest specie</h4>
# <hr>

# %% [markdown]
# <h3>3. Which types of species live in Dream island?</h3>

# %%
penguins[penguins['island'] == 'Dream']['species'].value_counts()
# Out:
# species
# Chinstrap    68
# Adelie       56
# Gentoo        0
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight:</h3>
# <h5>Chinstrap is the type of species that live the most in Dream Island </h4>
# <hr>

# %% [markdown]
# <h3>4. Most male species that found on 2007?</h3>

# %%
penguins[penguins['sex'] == 'male'] ['species'].value_counts()
# Out:
# species
# Adelie       79
# Gentoo       66
# Chinstrap    34
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight:</h3>
# <h5>Most male species that found on 2007 was Adelie</h4>
# <hr>

# %% [markdown]
# <h3>5. Who has the Deepest Bill Depth among Species?</h3>

# %%
penguins['bill_depth_mm'].max()
# Out:
# np.float64(21.5)

# %%
penguins[penguins['bill_depth_mm'] == 21.5]
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 19  Adelie  Torgersen            46.0           21.5              194.0
#
#     body_mass_g   sex  year  mass_kg
# 19       4200.0  male  2007      4.2

# %% [markdown]
# <h3>Insight:</h3>
# <h5>The Deepest Bill Depth among Species is Adelie</h4>
# <hr>

# %% [markdown]
# <h3>6. Who has the shortest Flipper among Species?</h3>

# %%
penguins['flipper_length_mm'].min()
# Out:
# np.float64(172.0)

# %%
penguins[penguins['flipper_length_mm'] == 172]
# Out:
#    species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 28  Adelie  Biscoe            37.9           18.6              172.0
#
#     body_mass_g     sex  year  mass_kg
# 28       3150.0  female  2007      3.2

# %% [markdown]
# <h3>Insight:</h3>
# <h5>The shortestt Flipper among Species is Adelie</h4>
# <hr>

# %% [markdown]
# <h3>7. Who has the Longest bill_length_mm among Species?</h3>

# %%
penguins['bill_length_mm'].max()
# Out:
# np.float64(59.6)

# %%
penguins[penguins['bill_length_mm'] == 59.6]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 185  Gentoo  Biscoe            59.6           17.0              230.0
#
#      body_mass_g   sex  year  mass_kg
# 185       6050.0  male  2007      6.0

# %% [markdown]
# <h3>Insight:</h3>
# <h5>Gentoo is have the longest Bill among the species that came from Biscoe</h4>
# <hr>

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen        39.10000       18.70000         181.000000
# 1  Adelie  Torgersen        39.50000       17.40000         186.000000
# 2  Adelie  Torgersen        40.30000       18.00000         195.000000
# 3  Adelie  Torgersen        43.92193       17.15117         200.915205
# 4  Adelie  Torgersen        36.70000       19.30000         193.000000
#
#    body_mass_g     sex  year  mass_kg
# 0  3750.000000    male  2007      3.8
# 1  3800.000000  female  2007      3.8
# 2  3250.000000  female  2007      3.2
# 3  4201.754386    male  2007      4.2
# 4  3450.000000  female  2007      3.4

# %% [markdown]
# penguins.tail()

# %% [markdown]
# <h1> Data Aggreation</h1>
# <h4> ilang species ng penguin ang nakatira per island?</h4>

# %%
species_island = penguins.groupby(['species','island','sex','year']).size()

# %%
species_island
# Out:
# species    island     sex     year
# Adelie     Biscoe     female  2007     5
#                               2008     9
#                               2009     8
#                       male    2007     5
#                               2008     9
#                               2009     8
#            Dream      female  2007     9
#                               2008     8
#                               2009    10
#                       male    2007    11
#                               2008     8
#                               2009    10
#            Torgersen  female  2007     8
#                               2008     8
#                               2009     8
#                       male    2007    12
#                               2008     8
#                               2009     8
# Chinstrap  Biscoe     female  2007     0
#                               2008     0
#                               2009     0
#                       male    2007     0
# ...

# %% [markdown]
# <h4>average weight of penguins per island and sex</h4>

# %%
avg_island_s = penguins.groupby(['species','island','sex'])['body_mass_g'].mean()

# %%
avg_island_s
# Out:
# species    island     sex
# Adelie     Biscoe     female    3369.318182
#                       male      4050.000000
#            Dream      female    3344.444444
#                       male      4008.620690
#            Torgersen  female    3395.833333
#                       male      3990.241228
# Chinstrap  Biscoe     female            NaN
#                       male              NaN
#            Dream      female    3527.205882
#                       male      3938.970588
#            Torgersen  female            NaN
#                       male              NaN
# Gentoo     Biscoe     female    4679.741379
#                       male      5411.011430
#            Dream      female            NaN
#                       male              NaN
#            Torgersen  female            NaN
#                       male              NaN
# Name: body_mass_g, dtype: float64

# %%
penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# mass_kg              0
# dtype: int64

# %% [markdown]
# <h1>Correlation Analysis</h1>
# <hr>
# <h3>Testing Correlational using Pearson R</h3>
# <hr>
# <p><b>Pearson R </b>can test correlational between two Variables, given that both Varaiables are <b>NUMERICAL DATA </b></p>
# <p><b>Pearson R</b> can test correlation between two variables, given that both variables are <b>NUMERICAL DATA</b>.</p>

# %%
flipper_mass= penguins['body_mass_g'].corr(penguins['flipper_length_mm'])

# %%
flipper_mass
# Out:
# np.float64(0.8712017673060114)

# %%
bill_length_mass= penguins['body_mass_g'].corr(penguins['bill_length_mm'])

# %%
bill_length_mass
# Out:
# np.float64(0.5951098244376305)

# %%
bill_depth_mass= penguins['body_mass_g'].corr(penguins['bill_depth_mm'])

# %%
bill_depth_mass
# Out:
# np.float64(-0.47191562118606645)

# %% [markdown]
# <h3>Testing Correlational between Numerical and Categorical Data</h3>

# %%
penguins[penguins['sex'] == 'male']['body_mass_g']
# Out:
# 0      3750.000000
# 3      4201.754386
# 5      3650.000000
# 7      4675.000000
# 8      3475.000000
#           ...
# 334    3800.000000
# 336    3950.000000
# 339    4000.000000
# 341    3775.000000
# 342    4100.000000
# Name: body_mass_g, Length: 179, dtype: float64

# %%
penguins[penguins['sex'] == 'female']['body_mass_g']
# Out:
# 1      3800.0
# 2      3250.0
# 4      3450.0
# 6      3625.0
# 12     3200.0
#         ...
# 335    3525.0
# 337    3650.0
# 338    3650.0
# 340    3400.0
# 343    3775.0
# Name: body_mass_g, Length: 165, dtype: float64

# %%
no_use, p_value = f_oneway(penguins[penguins['sex'] == 'male']['body_mass_g'],penguins[penguins['sex'] == 'female']['body_mass_g'])

# %%
p_value
# Out:
# np.float64(3.0226600487050246e-15)
